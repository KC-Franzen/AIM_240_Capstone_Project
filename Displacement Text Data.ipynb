# %%
# List of library and resources needed
import pandas as pd
import nltk 
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import PorterStemmer
import string
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import joblib

#nltk.download('stopwords')
#nltk.download('punkt')

# %%
# Grabbing text file from path
displacement_text = "C:/Users/krisf/Documents/AIM 240 Capstone Project/Physics_Openstax.txt"

# Open and read displacement_text and join the document text to a string
with open(displacement_text, 'r', encoding='utf-8') as file :
    read_text = ''.join(file.readlines())

pd.set_option('display.width',75)

# Tokenize the document into sentences
dt_sentences = sent_tokenize(read_text)

# Print the sentences to verify
for i, sentence in enumerate(dt_sentences) :
    print(f"Sentence {i+1}: {sentence}")
# Out:
# Sentence 1: Unless you have flown in an airplane, you have probably never traveled faster than 150 mph.
# Sentence 2: Can you imagine traveling in a train like the one shown in that goes over 300 mph?
# Sentence 3: Despite the high speed, the people riding in this train may not notice that they are moving at all unless they look out the window!
# Sentence 4: This is because motion, even motion at 300 mph, is relative to the observer.
# Sentence 5: In this chapter, you will learn why it is important to identify a reference frame in order to clearly describe motion.
# Sentence 6: For now, the motion you describe will be one-dimensional.
# Sentence 7: Within this context, you will learn the difference between distance and displacement as well as the difference between speed and velocity.
# Sentence 8: Then you will look at some graphing and problem-solving techniques.
# Sentence 9: Our study of physics opens with kinematics—the study of motion without considering its causes.
# ...

# %%
# Setting the stopwords to English
stop_words = set(stopwords.words('english'))

# Function to clean sentences
def clean_sentence(sentence) :
    # Convert to lowercase
    sentence = sentence.lower()
    # Tokenize the sentence
    words = word_tokenize(sentence)
    # Remove stopwords and punctuation
    words = [word for word in words if word not in stop_words and word not in string.punctuation]
    return ' '.join(words)

# Clean the sentences
cleaned_dt_sentences = [clean_sentence(sentence) for sentence in dt_sentences]

# Print the sentences to verify
for i, sentence in enumerate(cleaned_dt_sentences):
    print(f"Sentence {i + 1}: {sentence}")

print(type(cleaned_dt_sentences))
# Out:
# Sentence 1: unless flown airplane probably never traveled faster 150 mph
# Sentence 2: imagine traveling train like one shown goes 300 mph
# Sentence 3: despite high speed people riding train may notice moving unless look window
# Sentence 4: motion even motion 300 mph relative observer
# Sentence 5: chapter learn important identify reference frame order clearly describe motion
# Sentence 6: motion describe one-dimensional
# Sentence 7: within context learn difference distance displacement well difference speed velocity
# Sentence 8: look graphing problem-solving techniques
# Sentence 9: study physics opens kinematics—the study motion without considering causes
# Sentence 10: objects motion everywhere look
# Sentence 11: everything tennis game space-probe flyby planet neptune involves motion
# Sentence 12: resting heart moves blood veins
# Sentence 13: even inanimate objects atoms always moving
# Sentence 14: know something moving
# ...

# %%
# Create DataFrame with sentences
clean_dt_data = pd.DataFrame({'sentence': cleaned_dt_sentences, 'label': 1})

# Save the DataFrame to a CSV file
clean_dt_data.to_csv('clean_dt_data_with_labels.csv', index=False)

# Load the saved CSV file
loaded_dt_data = pd.read_csv('clean_dt_data_with_labels.csv')

# Display the first few rows of the loaded DataFrame
print(loaded_dt_data.head())
# Out:
#                                             sentence  label
# 0  unless flown airplane probably never traveled ...      1
# 1  imagine traveling train like one shown goes 30...      1
# 2  despite high speed people riding train may not...      1
# 3       motion even motion 300 mph relative observer      1
# 4  chapter learn important identify reference fra...      1
