# %%
# List of library and resources needed
import pandas as pd
import nltk 
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import PorterStemmer
import string
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import joblib

#nltk.download('stopwords')
#nltk.download('punkt')

# %%
# Grabbing text file from path
generic_text = "C:/Users/krisf/Documents/AIM 240 Capstone Project/Generic_Text.txt"

# Open and read generic_text and join the document text to a string
with open(generic_text, 'r', encoding='utf-8') as file :
    read_text = ''.join(file.readlines())

pd.set_option('display.width',75)

# Tokenize the document into sentences
gt_sentences = sent_tokenize(read_text)

# Print the sentences to verify
for i, sentence in enumerate(gt_sentences) :
    print(f"Sentence {i+1}: {sentence}")
# Out:
# Sentence 1: The cat jumped onto the windowsill.
# Sentence 2: I prefer tea over coffee in the mornings.
# Sentence 3: Are you going to the concert tomorrow?
# Sentence 4: The sunset painted the sky in shades of orange and pink.
# Sentence 5: My favorite color is turquoise.
# Sentence 6: Did you finish reading that book yet?
# Sentence 7: I love listening to jazz music on rainy days.
# Sentence 8: The smell of freshly baked bread fills the air.
# Sentence 9: Have you ever been to Paris?
# Sentence 10: I need to buy new shoes for work.
# Sentence 11: The ocean waves crash against the shore.
# Sentence 12: Let's go for a hike this weekend.
# Sentence 13: The flowers in the garden are blooming beautifully.
# Sentence 14: Did you see that shooting star last night?
# Sentence 15: I can't wait for summer vacation.
# Sentence 16: My phone battery is almost dead.
# Sentence 17: What's your favorite movie genre?
# Sentence 18: The traffic on the highway is terrible right now.
# ...

# %%
# Setting the stopwords to English
stop_words = set(stopwords.words('english'))

# Function to clean sentences using regex
def clean_sentence(sentence):
    # Convert to lowercase
    sentence = sentence.lower()
    # Remove non-alphanumeric characters using regex
    sentence = re.sub(r'[^a-zA-Z0-9\s]', '', sentence)
    # Tokenize the sentence
    words = word_tokenize(sentence)
    # Remove stopwords
    words = [word for word in words if word not in stop_words]
    return ' '.join(words)

# Clean the sentences
cleaned_gt_sentences = [clean_sentence(sentence) for sentence in gt_sentences]

# Print the sentences to verify
for i, sentence in enumerate(cleaned_gt_sentences):
    print(f"Sentence {i + 1}: {sentence}")

print(type(cleaned_gt_sentences))
# Out:
# Sentence 1: cat jumped onto windowsill
# Sentence 2: prefer tea coffee mornings
# Sentence 3: going concert tomorrow
# Sentence 4: sunset painted sky shades orange pink
# Sentence 5: favorite color turquoise
# Sentence 6: finish reading book yet
# Sentence 7: love listening jazz music rainy days
# Sentence 8: smell freshly baked bread fills air
# Sentence 9: ever paris
# Sentence 10: need buy new shoes work
# Sentence 11: ocean waves crash shore
# Sentence 12: lets go hike weekend
# Sentence 13: flowers garden blooming beautifully
# Sentence 14: see shooting star last night
# Sentence 15: cant wait summer vacation
# Sentence 16: phone battery almost dead
# Sentence 17: whats favorite movie genre
# Sentence 18: traffic highway terrible right
# Sentence 19: im thinking starting new hobby
# Sentence 20: tried new restaurant downtown
# Sentence 21: snow melting spring finally
# Sentence 22: believe aliens
# Sentence 23: im feeling sleepy lunch
# ...

# %%
# Create DataFrame with sentences
clean_gt_data = pd.DataFrame({'sentence': cleaned_gt_sentences, 'label': 2})

# Save the DataFrame to a CSV file
clean_gt_data.to_csv('clean_gt_data_with_labels.csv', index=False)

# Load the saved CSV file
loaded_gt_data = pd.read_csv('clean_gt_data_with_labels.csv')

# Display the first few rows of the loaded DataFrame
print(loaded_gt_data.head())
# Out:
#                                 sentence  label
# 0             cat jumped onto windowsill      2
# 1             prefer tea coffee mornings      2
# 2                 going concert tomorrow      2
# 3  sunset painted sky shades orange pink      2
# 4               favorite color turquoise      2
